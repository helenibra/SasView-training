# %% [markdown]
# # Premiers pas dans https://gitub.u-bordeaux.fr/
#
# Si vous n'êtes pas rattaché à l'université, vous devez vous connecter de manière standard. Après que vous ayez reçu un mail de bienvenue.
#
# Votre nom et email ont été transmis au service de L'université de Bordeaux pour que les approbations se passent au plus vite.
#
# Vous n'en aurez réellement besoin que jeudi matin.

# %% [markdown]
# ![welcome_gitlab.png](attachment:f8d1facc-f6a3-4c5b-ac9d-7e3c5bbc0ca7.png)

# %% [markdown]
# ![premiere_connexion.png](attachment:bd086f8f-baf0-4e64-9a42-a3e0d02f821d.png)

# %% [markdown]
# ![ajout_cle_ssh.png](attachment:44df7fbc-69f1-4beb-b88a-bbfa2a572823.png)

# %% [markdown]
# ![ajout_cle_public.png](attachment:c0eb31ee-8f16-41d7-8013-4c2c34ff7049.png)

# %% [markdown]
# Vous devriez maintenant être en mesure de travailler avec un dépôt.
#
# - Cloner le dépôt "Parcours Python"
# > git clone git@gitub.u-bordeaux.fr:anf_python_r/parcours_python.git
#
# - Cloner votre dépoôt à votre nom
# > git clone ...
